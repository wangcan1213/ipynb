# %% [markdown]
# ## regress帮助文件

# %%
# %run regress.py -h
# Out:
# usage: regress.py [-h] [-f FILE] [-s SAVE] [-t TRANSFORM] [-sp SPLIT]
#                   [-a ALGORITHM] [-p PARAMETER] [-c CONFIDENCE] [-d DROP]
#                   [-k KFOLD] [-rs RANDOM_SEED] [-pr PARA_RANGE] [-cr C_RANGE]
#                   [-gr GAMMA_RANGE] [-rr REG_RANGE] [-nt NUM_TREES]
#                   [-lr LEARNING_RATE]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f FILE, --file FILE  the file name of the csv-format data file without
#                         extension ",csv", default "data". The file should be
#                         in the same fold as this python script
#   -s SAVE, --save SAVE  specify a name and then save the model. The model will
#                         be saved in the same fold as this python script, with
#                         the extension ".rmodel". By default, the model will
#                         not be saved
#   -t TRANSFORM, --transform TRANSFORM
# ...

# %% [markdown]
# ## 通过随机森林+Grid Search训练回归模型

# %%
# %run regress.py -pr 1,10,1
# Out:
# Data: nonrandom train-test split, the whole data of certain positions are used for test
# X_train shape: (504, 50)
# X_test shape: (175, 50)
#
#
# Do grid search for best min_samples_leaf....
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=1; dist=16.989
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=2; dist=16.743
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=3; dist=16.853
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=4; dist=16.578
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=5; dist=15.826
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=6; dist=16.540
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=7; dist=15.285
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=8; dist=15.513
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=9; dist=16.356
# ...

# %% [markdown]
# ## 通过GBDT+Grid Search训练分类模型

# %%
# %run classify.py -a gb
# Out:
# Data: nonrandom train-test split, the whole data of certain positions are used for test
# X_train shape: (504, 50)
# X_test shape: (175, 50)
#
#
# Do grid search for best min_samples_leaf....
# Grid searching process: min_samples_leaf=1; accuracy=0.0000
# Grid searching process: min_samples_leaf=2; accuracy=0.0000
# Grid searching process: min_samples_leaf=3; accuracy=0.0000
# Grid searching process: min_samples_leaf=4; accuracy=0.0000
# Grid searching process: min_samples_leaf=5; accuracy=0.0000
# Grid searching process: min_samples_leaf=6; accuracy=0.0000
# Grid searching process: min_samples_leaf=7; accuracy=0.0000
# Grid searching process: min_samples_leaf=8; accuracy=0.0000
# Grid searching process: min_samples_leaf=9; accuracy=0.0000
# Grid searching process: min_samples_leaf=10; accuracy=0.0000
# Grid searching process: min_samples_leaf=11; accuracy=0.0000
# Grid searching process: min_samples_leaf=12; accuracy=0.0000
# ...

# %% [markdown]
# ## 训练带置信度的回归模型

# %%
# %run regress.py -pr 1,10,1 -c 0.4,1
# Out:
# Data: nonrandom train-test split, the whole data of certain positions are used for test
# X_train shape: (504, 50)
# X_test shape: (175, 50)
#
#
# Do grid search for best min_samples_leaf....
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=1; dist=15.525
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=2; dist=16.230
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=3; dist=15.940
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=4; dist=15.968
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=5; dist=15.922
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=6; dist=16.068
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=7; dist=16.248
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=8; dist=16.244
# Grid searching process: min_samples_leaf_x=1; min_samples_leaf_y=9; dist=16.446
# ...
